# %%
name = input('Write your name')
# Out:
# Write your name Sham

# %%
name
# Out:
# 'Sham'

# %%
print(f'Your Good name is {name}')
# Out:
# Your Good name is Sham

# %%
type(name)
# Out:
# str

# %%
age = int(input('Write your age in int format only'))
# Out:
# Write your age in int format only 45

# %%
age
# Out:
# 45

# %%
type(age)
# Out:
# int

# %%
height = float(input('Write your height in float'))
# Out:
# Write your height in float 4.258

# %%
height
# Out:
# 4.258

# %%
weight = float(input('Write your weight'))
# Out:
# Write your weight hello
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 weight = float(input('Write your weight'))
#
# ValueError: could not convert string to float: 'hello'

# %% [markdown]
# # type casting

# %% [markdown]
# Changing one data type to the other data type

# %%
a = '11'

# %%
type(a)
# Out:
# str

# %%
# We have to convert string data into int

# %%
int(a)
# Out:
# 11

# %%
int('101')
# Out:
# 101

# %%
int(51.214)
# Out:
# 51

# %%
int('hello')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 int('hello')
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
age = 5

# %%
age * 12
# Out:
# 60

# %%
num = 5.5

# %%
int(num)
# Out:
# 5

# %% [markdown]
# 1. What is Python?
