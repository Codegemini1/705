# %% [markdown]
# # Data Types

# %% [raw]
# Int : Complete Number
# Eg;:-> No of Family Members
# -----> 5,3,2

# %%
5
# Out:
# 5

# %%
type(5)
# Out:
# int

# %%
type(1293)
# Out:
# int

# %% [raw]
# Float: Numbers in decimal format
# Eg:-> Height ?
# ----> 5.3, 4.8, 6.3
# Eg:-> Weight ?
# ----> 55.200, 78.100

# %%
5.3
# Out:
# 5.3

# %%
type(5.3)
# Out:
# float

# %%
type(55.200)
# Out:
# float

# %%
type(2.0)
# Out:
# float

# %%
type(2)
# Out:
# int

# %% [raw]
# Complex Number:- Vector Values (Imaginary Plotting)
# eg:- 4 + 3j

# %%
4 + 3j
# Out:
# (4+3j)

# %%
-1 + 3j
# Out:
# (-1+3j)

# %%
type(-1 + 3j)
# Out:
# complex

# %%
type(4 + 3j)
# Out:
# complex

# %% [raw]
# String:-> Words, letters, sentences
# single :-> 'hello' / "hello"
# Multiple Line ;-> '''
#
#
# '''

# %%
'hello'
# Out:
# 'hello'

# %%
"hello"
# Out:
# 'hello'

# %%
print('hello')
# Out:
# hello

# %%
print("Hello")
# Out:
# Hello

# %%
print(''' This is my first line.
This is my 2nd line.
This is my 3rd line''')
# Out:
#  This is my first line.
# This is my 2nd line.
# This is my 3rd line

# %%
print(' This is my first line.
This is my 2nd line.
This is my 3rd line')
# Out:
#   Cell In[46], line 1
#     print(' This is my first line.
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# # Interview Question ---> How to write multiple line sentences ?

# %%
type('hello')
# Out:
# str

# %%
type('Python')
# Out:
# str

# %% [raw]
# Boolean Values :-> True and False

# %%
10 > 50
# Out:
# False

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type
