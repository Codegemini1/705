# %%
x = 5

# %%
print(x)
# Out:
# 5

# %%
y = 10

# %%
print(y)
# Out:
# 10

# %%
x + y
# Out:
# 15

# %%
x_1 = 'hello'

# %%
print(x_1)
# Out:
# hello

# %%
1x = 'Python'
# Out:
#   Cell In[15], line 1
#     1x = 'Python'
#     ^
# SyntaxError: invalid decimal literal

# %%
@ = 8
# Out:
#   Cell In[17], line 1
#     @ = 8
#       ^
# SyntaxError: invalid syntax

# %%
first_name = 'Vaibhav'

# %%
first name = 'Vaibhav'
# Out:
#   Cell In[21], line 1
#     first name = 'Vaibhav'
#           ^
# SyntaxError: invalid syntax

# %%
last_name = 'Bhosale'

# %%
print(first_name)
# Out:
# Vaibhav

# %%
print(last_name)
# Out:
# Bhosale

# %%
print(first_name + last_name)
# Out:
# VaibhavBhosale

# %%
first_name + ' ' + last_name
# Out:
# 'Vaibhav Bhosale'

# %%
price = 120

# %%
username = 'abhi45'

# %%
_age = 40

# %%
# Invalid

# %%
2count = 4
# Out:
#   Cell In[41], line 1
#     2count = 4
#     ^
# SyntaxError: invalid decimal literal

# %%
user name = 'Rock75'
# Out:
#   Cell In[43], line 1
#     user name = 'Rock75'
#          ^
# SyntaxError: invalid syntax

# %%
type = 10

# %%
type
# Out:
# 10

# %%
type(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 type(1)
#
# TypeError: 'int' object is not callable

# %%
# Multiple assignment

# %%
a, b, c, d = 10,20,30,40

# %%
a
# Out:
# 10

# %%
b
# Out:
# 20

# %%
c
# Out:
# 30

# %%
d
# Out:
# 40

# %%
x = y = z = 0

# %%
x
# Out:
# 0

# %%
y
# Out:
# 0

# %%
z
# Out:
# 0

# %% [markdown]
# # Arithmetic Operators

# %%
a = 7
b = 3

# %%
a + b
# Out:
# 10

# %%
a - b
# Out:
# 4

# %%
a * b
# Out:
# 21

# %%
a / b
# Out:
# 2.3333333333333335

# %%
a % b
# Out:
# 1

# %%
a ** b
# Out:
# 343

# %%
2 ** 2
# Out:
# 4

# %%
2 ** 3
# Out:
# 8

# %% [markdown]
# # Logical Operators

# %%
True & True
# Out:
# True

# %%
True & False
# Out:
# False

# %%
False & True
# Out:
# False

# %%
False & False
# Out:
# False

# %%
5 > 1
# Out:
# True

# %%
10 > 2
# Out:
# True

# %%
5 > 1 and 10 > 2    # True and True
# Out:
# True

# %%
5 > 1 and 10 < 2   #True and False
# Out:
# False

# %%
# Or

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
5 > 1 or 10 > 2    # True and True
# Out:
# True

# %%
5 > 1 or 10 < 2    # True and False ---> True OR
# Out:
# True

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
# Comparison Operators

# %%
5 > 3
# Out:
# True

# %%
10 < 4
# Out:
# False

# %%
10 > 10
# Out:
# False

# %%
10 >= 10
# Out:
# True

# %%
5 < 5
# Out:
# False

# %%
5 <= 5
# Out:
# True

# %%
10 == 10
# Out:
# True

# %%
# 10 = 10

# %% [markdown]
# # What is the diff b/w = and == ?

# %%
a = 5

# %%
5 == 5
# Out:
# True

# %%
4 == 5
# Out:
# False

# %%
'a' == 'a'
# Out:
# True

# %%
'a' == 'b'
# Out:
# False

# %%
5 != 1
# Out:
# True
