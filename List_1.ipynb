# %%
l = [1,3,4,2,5,3]

# %%
l
# Out:
# [1, 3, 4, 2, 5, 3]

# %%
type(l)
# Out:
# list

# %%
mix = [1, 3.23, 'Hello', True, 10 + 5j]

# %%
mix
# Out:
# [1, 3.23, 'Hello', True, (10+5j)]

# %%
names = ['Om', 'Abhay', 'Ganesh', 'Sam']

# %%
names
# Out:
# ['Om', 'Abhay', 'Ganesh', 'Sam']

# %%
# Slicing Operation

# %%
l = [51, 35, 42, 55]

# %%
l
# Out:
# [51, 35, 42, 55]

# %%
l[0]
# Out:
# 51

# %%
l[1]
# Out:
# 35

# %%
l[2]
# Out:
# 42

# %%
l[3]
# Out:
# 55

# %%
l[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 l[4]
#
# IndexError: list index out of range

# %%
l
# Out:
# [51, 35, 42, 55]

# %%
l[-1]
# Out:
# 55

# %%
l[-2]
# Out:
# 42

# %%
l[-3]
# Out:
# 35

# %%
l[-4]
# Out:
# 51

# %%
l
# Out:
# [51, 35, 42, 55]

# %%
l[0:3]
# Out:
# [51, 35, 42]

# %%
l[0:2]
# Out:
# [51, 35]

# %%
m = [4,6,5,3,7,5,7,8]

# %%
m
# Out:
# [4, 6, 5, 3, 7, 5, 7, 8]

# %%
m[0:5]
# Out:
# [4, 6, 5, 3, 7]

# %%
m[1:4]
# Out:
# [6, 5, 3]

# %%
m[0:]   # empty means till end point
# Out:
# [4, 6, 5, 3, 7, 5, 7, 8]

# %%
m[:]
# Out:
# [4, 6, 5, 3, 7, 5, 7, 8]

# %%
m[2:]
# Out:
# [5, 3, 7, 5, 7, 8]

# %%
m[::1] # start index : end index : jump size
# Out:
# [4, 6, 5, 3, 7, 5, 7, 8]

# %%
m[::2]
# Out:
# [4, 5, 7, 7]

# %%
m[::3]
# Out:
# [4, 3, 7]

# %%
a = [1,2,3,4,5,6,7,8]

# %%
a[::1]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
a[::2]
# Out:
# [1, 3, 5, 7]

# %%
a[1:]
# Out:
# [2, 3, 4, 5, 6, 7, 8]

# %%
a[1::2]
# Out:
# [2, 4, 6, 8]

# %%
a
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
a[:]
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
a[::-1]
# Out:
# [8, 7, 6, 5, 4, 3, 2, 1]

# %%
a[::-2]
# Out:
# [8, 6, 4, 2]

# %%
# How to update list
