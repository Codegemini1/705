# %% [markdown]
# # Nested List

# %%
p = [1,2,3,4,[10,20,30,40], 5, 6]

# %%
p
# Out:
# [1, 2, 3, 4, [10, 20, 30, 40], 5, 6]

# %%
p[2]
# Out:
# 3

# %%
p[3]
# Out:
# 4

# %%
p[4]
# Out:
# [10, 20, 30, 40]

# %%
p
# Out:
# [1, 2, 3, 4, [10, 20, 30, 40], 5, 6]

# %%
p[4]
# Out:
# [10, 20, 30, 40]

# %%
p[4][1]
# Out:
# 20

# %% [markdown]
# # How to replace elelemts of list

# %%
l = ['A', 'B', 'C', 'D']

# %%
l
# Out:
# ['A', 'B', 'C', 'D']

# %%
l[1]
# Out:
# 'B'

# %%
l[1]
# Out:
# 'B'

# %%
l[1] = 'boy'

# %%
l
# Out:
# ['A', 'boy', 'C', 'D']

# %%
l[2]
# Out:
# 'C'

# %%
l[2] = 'code'

# %%
l
# Out:
# ['A', 'boy', 'code', 'D']

# %%
# Using inbuild function

# %%
l
# Out:
# ['A', 'boy', 'code', 'D']

# %%
l.append(10)

# %%
l
# Out:
# ['A', 'boy', 'code', 'D', 10]

# %%
l.append([1,2,3,4])

# %%
l
# Out:
# ['A', 'boy', 'code', 'D', 10, [1, 2, 3, 4]]

# %%
l.extend([10,20,30,40])

# %%
l
# Out:
# ['A', 'boy', 'code', 'D', 10, [1, 2, 3, 4], 10, 20, 30, 40]

# %%
l.extend([1,20,40])

# %%
l
# Out:
# ['A', 'boy', 'code', 'D', 10, [1, 2, 3, 4], 10, 20, 30, 40, 1, 20, 40]

# %%
l.count(10)
# Out:
# 2

# %%
l.count(30)
# Out:
# 1

# %%
l.count(20)
# Out:
# 2

# %%
l
# Out:
# ['A', 'boy', 'code', 'D', 10, [1, 2, 3, 4], 10, 20, 30, 40, 1, 20, 40]

# %%
l.insert(1, 'New_Obj')

# %%
l
# Out:
# ['A',
#  'New_Obj',
#  'boy',
#  'code',
#  'D',
#  10,
#  [1, 2, 3, 4],
#  10,
#  20,
#  30,
#  40,
#  1,
#  20,
#  40]

# %%
m = [10,20,30]

# %%
m
# Out:
# [10, 20, 30]

# %%
m.insert(2, 1.5)

# %%
m
# Out:
# [10, 20, 1.5, 30]

# %%
m.remove(20)

# %%
m
# Out:
# [10, 1.5, 30]

# %%
l
# Out:
# ['A',
#  'New_Obj',
#  'boy',
#  'code',
#  'D',
#  10,
#  [1, 2, 3, 4],
#  10,
#  20,
#  30,
#  40,
#  1,
#  20,
#  40]

# %%
l.remove('D')

# %%
l
# Out:
# ['A', 'New_Obj', 'boy', 'code', 10, [1, 2, 3, 4], 10, 20, 30, 40, 1, 20, 40]

# %%
l.pop()
# Out:
# 40

# %%
l
# Out:
# ['A', 'New_Obj', 'boy', 'code', 10, [1, 2, 3, 4], 10, 20, 30, 40, 1, 20]

# %%
l.pop()
# Out:
# 20

# %%
l
# Out:
# ['A', 'New_Obj', 'boy', 'code', 10, [1, 2, 3, 4], 10, 20, 30, 40, 1]

# %%
l.index('boy')
# Out:
# 2

# %%
l.index(10)  #nearest index number
# Out:
# 4

# %%
l
# Out:
# ['A', 'New_Obj', 'boy', 'code', 10, [1, 2, 3, 4], 10, 20, 30, 40, 1]

# %%
l.reverse()

# %%
l
# Out:
# [1, 40, 30, 20, 10, [1, 2, 3, 4], 10, 'code', 'boy', 'New_Obj', 'A']

# %%
m
# Out:
# [10, 1.5, 30]

# %%
m[::-1]
# Out:
# [30, 1.5, 10]

# %%
m
# Out:
# [10, 1.5, 30]

# %%
m.reverse()

# %%
m
# Out:
# [30, 1.5, 10]
