# %%
print(10)
# Out:
# 10

# %%
print('Hello Python')
# Out:
# Hello Python

# %%
print(25)  # int 
print(3.12) # float
print(True) # boolean
print('A')  # String
# Out:
# 25
# 3.12
# True
# A

# %%
print('X', 'Y', 'Z')
# Out:
# X Y Z

# %%
print('Hello', 10, 3.5)
# Out:
# Hello 10 3.5

# %%
print('Hello' 10 3.5)
# Out:
#   Cell In[7], line 1
#     print('Hello' 10 3.5)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# This is code for project delta
a = 6
b = 7
print(a + b)
# Out:
# 13

# %%
name = 'Vaibhav'
age = 20
height = 5.6

# %%
student-name = 'Y'
# Out:
#   Cell In[10], line 1
#     student-name = 'Y'
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
student name = 'Y'
# Out:
#   Cell In[11], line 1
#     student name = 'Y'
#             ^
# SyntaxError: invalid syntax

# %%
student_name = 'Y'

# %%
studentname = 'Y'

# %%
2age = 70
# Out:
#   Cell In[14], line 1
#     2age = 70
#     ^
# SyntaxError: invalid decimal literal

# %%
age2 = 70

# %%
# Concatination operations

# %%
print('A' + 'b')  # str + str
# Out:
# Ab

# %%
print('A' + 10 ) # str + int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print('A' + 10 )
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(10 + 5) #int + int
# Out:
# 15

# %%
print(10 + 3.2) #int + float
# Out:
# 13.2

# %%
print('A' + '10' ) # str + str
# Out:
# A10

# %%
type('10')
# Out:
# str

# %%
type(10)
# Out:
# int

# %%
name = 'Vaibhav'
surname = 'Bhosale'

# %%
print('My name is')
# Out:
# My name is

# %%
print('My name is' + name )
# Out:
# My name isVaibhav

# %%
print(f'My first name is {name} and my last name is {surname}')
# Out:
# My first name is Vaibhav and my last name is Bhosale

# %%
age = 55

# %%
print(f'My name is {name} and surname is {surname}. My age is {age}')
# Out:
# My name is Vaibhav and surname is Bhosale. My age is 55

# %%
print('Hello', 8, True, 3.1)
# Out:
# Hello 8 True 3.1

# %%
print('First_Name' + ' ' + 'last_name')
# Out:
# First_Name last_name

# %%
print('Hello' * 5)
# Out:
# HelloHelloHelloHelloHello

# %% [markdown]
# # Taking user Input

# %%
name = input()
print(f'Your Good name is {name}')
# Out:
#  Rock
# Your Good name is Rock

# %%
name = input('Please write your first name')
print(f'Your Good name is {name}')
# Out:
# Please write your first name xyz
# Your Good name is xyz

# %%
first_name = input('Enter your first name')
last_name = input('Enter your Last name or surname')
print(f'Your good name is {first_name} and last name is {last_name} ')
# Out:
# Enter your first name Alex
# Enter your Last name or surname rock
# Your good name is Alex and last name is rock

# %%
color = input('Enter your fev color')
# Out:
# Enter your fev color red

# %%
color
# Out:
# 'red'

# %%
type(color)
# Out:
# str

# %%
marks = input('Enter Your marks')
# Out:
# Enter Your marks 12

# %%
marks
# Out:
# '12'

# %%
type(marks)
# Out:
# str

# %%
'12'
# Out:
# '12'

# %%
# How to take int input

# %%
age = int(input())
# Out:
#  5

# %%
# Follow theory of 5 examples
